# %% [markdown]
# <a href="https://colab.research.google.com/github/Sam01324/Pythoncompletebook.ipynb/blob/main/python_complete_book.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

arr = np.array([56,78,89,92,67])
print("Array:", arr)
print("Mean:", np.mean(arr))
print("Max:", np.max(arr))
print("Min:", np.min(arr))
# Out:
# Array: [56 78 89 92 67]
# Mean: 76.4
# Max: 92
# Min: 56

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load Dataset
df = sns.load_dataset('tips')

# Step 2: Explore Data
print("Head:\n", df.head())
print("\nInfo:\n")
df.info()

# Step 3: Average tip per day
print("\nAverage Tip by Day:\n", df.groupby('day')['tip'].mean())

# Step 4: Count of smokers
print("\nSmoker Count:\n", df['smoker'].value_counts())

# Step 5a: Barplot – Avg total_bill by sex
sns.barplot(x='sex', y='total_bill', data=df)
plt.title("Average Total Bill by Gender")
plt.show()

# Step 5b: Violinplot – Tip by Day
sns.violinplot(x='day', y='tip', data=df)
plt.title("Tip Distribution by Day")
plt.show()

# Step 5c: Heatmap of Correlations
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# Step 6: Top 5 tips
print("\nTop 5 Tips:\n", df.sort_values('tip', ascending=False).head())

# Step 7: Check & Fill missing values
print("\nMissing Values:\n", df.isnull().sum())
df['size'] = df['size'].fillna(df['size'].mean())  # Example
# Step 8: Evaluate Model
from sklearn.metrics import accuracy_score, confusion_matrix

# Predict on test data
y_pred = model.predict(X_test)

# Accuracy check
print("✅ Model Accuracy:", accuracy_score(y_test, y_pred))

# Confusion matrix to analyze performance
print("🔹 Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Head:
#     total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
#
# Average Tip by Day:
#  day
# Thur    2.771452
# Fri     2.734737
# ...

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset('titanic')
print(df.head())
df.info()
print(df['survived'].value_counts())
print(df['sex'].value_counts())
print(df.isnull().sum())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
import pandas as pd
data = {
    'Name': ['Satyam', 'Ravi', 'Neha'],
    'Maths': [90, 80, 85],
    'Science': [95, 85, 88]
}
df = pd.DataFrame(data)
print(df.head())
print(df.describe())
# Out:
#      Name  Maths  Science
# 0  Satyam     90       95
# 1    Ravi     80       85
# 2    Neha     85       88
#        Maths    Science
# count    3.0   3.000000
# mean    85.0  89.333333
# std      5.0   5.131601
# min     80.0  85.000000
# 25%     82.5  86.500000
# 50%     85.0  88.000000
# 75%     87.5  91.500000
# max     90.0  95.000000

# %%
import numpy as np

arr = np.array([56,78,89,92,67])
print("Array:", arr)
print("Median:", np.median(arr))
print("Std:", np.std(arr))
# Out:
# Array: [56 78 89 92 67]
# Median: 78.0
# Std: 13.484806264830059

# %%
print("\nHead:\n"import pandas as pd

data = {
    "Name": ["Satyam", "Ravi", "Neha"],
    "Maths": [85, 78, 92],
    "Science": [90, 82, 89]
}

df = pd.DataFrame(data)
print(df)

# Explore
print("\nHead:\n", df.head(2))
print("\nDescribe:\n", df.describe())
print("\nInfo:\n")
df.info()
# Out:
#      Name  Maths  Science
# 0  Satyam     85       90
# 1    Ravi     78       82
# 2    Neha     92       89
#
# Head:
#       Name  Maths  Science
# 0  Satyam     85       90
# 1    Ravi     78       82
#
# Describe:
#         Maths    Science
# count    3.0   3.000000
# mean    85.0  87.000000
# std      7.0   4.358899
# min     78.0  82.000000
# 25%     81.5  85.500000
# 50%     85.0  89.000000
# 75%     88.5  89.500000
# max     92.0  90.000000
#
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Maths    3 non-null      int64
#  2   Science  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
import pandas as pd
data = {
"Name":["satyam","ravi","neha"],
"Maths":[10,10,10],
"Science ":[10,10,10],
"Total":[20,20,20]
}

df=pd.DataFrame(data)
print(df)

print("\nHead:\n",df.head(2))
print("\nDescribe:\n",df.describe())
print("\nInfo:\n")
df.info()
# Out:
#      Name  Maths  Science   Total
# 0  satyam     10        10     20
# 1    ravi     10        10     20
# 2    neha     10        10     20
#
# Head:
#       Name  Maths  Science   Total
# 0  satyam     10        10     20
# 1    ravi     10        10     20
#
# Describe:
#         Maths  Science   Total
# count    3.0       3.0    3.0
# mean    10.0      10.0   20.0
# std      0.0       0.0    0.0
# min     10.0      10.0   20.0
# 25%     10.0      10.0   20.0
# 50%     10.0      10.0   20.0
# 75%     10.0      10.0   20.0
# max     10.0      10.0   20.0
#
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      3 non-null      object
#  1   Maths     3 non-null      int64
#  2   Science   3 non-null      int64
#  3   Total     3 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 228.0+ bytes

# %%
# Filter those who got >10 in Science
print("\nTop Science students:\n", df[df["Science"] > 10])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Science'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-4b963d23d0b5> in <cell line: 0>()
#       1 # Filter those who got >10 in Science
# ...

# %%
# Save
df.to_csv("students.csv", index=False)

# Load
new_df = pd.read_csv("students.csv")
print("Loaded from CSV:\n", new_df)
# Out:
# Loaded from CSV:
#       Name  Maths  Science   Total
# 0  satyam     10        10     20
# 1    ravi     10        10     20
# 2    neha     10        10     20

# %%
# Save as CSV (without index column)
df.to_csv("students.csv", index=False)

# Load it again
loaded_df = pd.read_csv("students.csv")

# Check
print("Loaded DataFrame:\n", loaded_df)
print("Columns:", loaded_df.columns)
print("Shape:", loaded_df.shape)
print("Mean of each subject:\n", loaded_df.mean(numeric_only=True))
# Out:
# Loaded DataFrame:
#       Name  Maths  Science   Total
# 0  satyam     10        10     20
# 1    ravi     10        10     20
# 2    neha     10        10     20
# Columns: Index(['Name', 'Maths', 'Science ', 'Total'], dtype='object')
# Shape: (3, 4)
# Mean of each subject:
#  Maths       10.0
# Science     10.0
# Total       20.0
# dtype: float64

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

plt.plot(x, y, color='blue', marker='o')
plt.title("Simple Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# %%
name = "SatyamPandey"
x = list(range(1, len(name)+1))   # [1, 2, 3, 4, 5, 6]
y = [ord(ch) for ch in name]      # ASCII values of each character

plt.plot(x, y, marker='*', color='purple')
plt.title("Graph of ASCII values of letters in name")
plt.xlabel("Letter Position")
plt.ylabel("ASCII Value")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

students = ['Satyam', 'Ravi', 'Neha']
marks = [85, 90, 78]

plt.bar(students, marks, color='skyblue')
plt.title("Marks of Students")
plt.xlabel("Student Name")
plt.ylabel("Marks")
plt.grid(True, axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt

subjects = ['Maths', 'Science', 'English']
scores = [30, 40, 30]

plt.pie(scores, labels=subjects, autopct='%1.1f%%')
plt.title("Subject-wise Score Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt

Tasks = ['Execise', 'dsa(python)', 'reading ', 'games']
Time = [15,60,20,100]

plt.pie(Time, labels = Tasks, autopct='%1.1f%%')
plt.title("Tasks wise Time distribution")
plt.show()

# %%
import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Addition: [5 7 9]
# Subtraction: [-3 -3 -3]
# Multiplication: [ 4 10 18]
# Division: [0.25 0.4  0.5 ]

# %%
import numpy as np

matrix1 = np.array([[1, 2], [3, 4]])
matrix2 = np.array([[5, 6], [7, 8]])

print("Addition:\n", matrix1 + matrix2)
print("Subtraction:\n", matrix1 - matrix2)
print("Multiplication:\n", matrix1 * matrix2)  # Element-wise
print("Matrix Multiplication:\n", np.dot(matrix1, matrix2))  # Matrix product
print("Transpose:\n", matrix1.T)
# Out:
# Addition:
#  [[ 6  8]
#  [10 12]]
# Subtraction:
#  [[-4 -4]
#  [-4 -4]]
# Multiplication:
#  [[ 5 12]
#  [21 32]]
# Matrix Multiplication:
#  [[19 22]
#  [43 50]]
# Transpose:
#  [[1 3]
#  [2 4]]

# %%
ch = 'A'
print("Character:", ch)
print("ASCII:", ord(ch))

ascii_num = 97
print("ASCII Number:", ascii_num)
print("Character:", chr(ascii_num))
# Out:
# Character: A
# ASCII: 65
# ASCII Number: 97
# Character: a

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, marker='o', linestyle='-.', color='blue')
plt.title("Line Plot with Markers")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# %%
import pandas as pd

data = {
    'Name': ['Satyam', 'Neha', 'Ravi', 'Priya'],
    'Maths': [88, 92, 79, 95],
    'Science': [91, 89, 84, 90],
    'English': [85, 87, 80, 88]
}

df = pd.DataFrame(data)
print(df)
print("Head:\n", df.head())
print("\nDescribe:\n", df.describe())
print("\nInfo:")
df.info()
# Out:
#      Name  Maths  Science  English
# 0  Satyam     88       91       85
# 1    Neha     92       89       87
# 2    Ravi     79       84       80
# 3   Priya     95       90       88
# Head:
#       Name  Maths  Science  English
# 0  Satyam     88       91       85
# 1    Neha     92       89       87
# 2    Ravi     79       84       80
# 3   Priya     95       90       88
#
# Describe:
#             Maths    Science    English
# count   4.000000   4.000000   4.000000
# mean   88.500000  88.500000  85.000000
# std     6.952218   3.109126   3.559026
# min    79.000000  84.000000  80.000000
# 25%    85.750000  87.750000  83.750000
# 50%    90.000000  89.500000  86.000000
# 75%    92.750000  90.250000  87.250000
# max    95.000000  91.000000  88.000000
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     4 non-null      object
# ...

# %%
df = pd.read_csv("data.csv", index_col=0)
print(df.head())
Name,Maths,Science,English
Satyam,88,91,85
Neha,92,89,87
Ravi,79,84,80
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-52bf645901b0> in <cell line: 0>()
# ----> 1 df = pd.read_csv("data.csv", index_col=0)
#       2 print(df.head())
#       3 Name,Maths,Science,English
#       4 Satyam,88,91,85
#       5 Neha,92,89,87
#
# ...

# %%
import pandas as pd

data = {
    'Name': ['Satyam', 'Neha', 'Ravi', None],
    'Maths': [88, 92, None, 95],
    'Science': [91, None, 84, 90]
}

df = pd.DataFrame(data)
print("Original:\n", df)

# Missing values count
print("\nMissing:\n", df.isnull().sum())

# Fill missing names with "Unknown"
df['Name'] = df['Name'].fillna("Unknown")

# Fill missing marks with 0
df = df.fillna(0)

print("\nCleaned:\n", df)
# Out:
# Original:
#       Name  Maths  Science
# 0  Satyam   88.0     91.0
# 1    Neha   92.0      NaN
# 2    Ravi    NaN     84.0
# 3    None   95.0     90.0
#
# Missing:
#  Name       1
# Maths      1
# Science    1
# dtype: int64
#
# Cleaned:
#        Name  Maths  Science
# 0   Satyam   88.0     91.0
# 1     Neha   92.0      0.0
# 2     Ravi    0.0     84.0
# 3  Unknown   95.0     90.0

# %%
import pandas as pd

data = {
    'Name': ['Satyam', 'Neha', 'Ravi'],
    'Maths': [88, 92, 79],
    'Science': [91, 89, 84]
}

df = pd.DataFrame(data)

# Ascending order (by Maths)
print("\nSorted by Maths (asc):\n", df.sort_values(by='Maths'))

# Descending order (by Science)
print("\nSorted by Science (desc):\n", df.sort_values(by='Science', ascending=False))
# Students who scored more than 85 in Maths
high_scores = df[df['Maths'] > 85]
print("\nMaths > 85:\n", high_scores)

# Students who scored more than 90 in Science
science_topper = df[df['Science'] > 90]
print("\nScience > 90:\n", science_topper)
# Out:
# Sorted by Maths (asc):
#       Name  Maths  Science
# 2    Ravi     79       84
# 0  Satyam     88       91
# 1    Neha     92       89
#
# Sorted by Science (desc):
#       Name  Maths  Science
# 0  Satyam     88       91
# 1    Neha     92       89
# 2    Ravi     79       84
#
# Maths > 85:
#       Name  Maths  Science
# 0  Satyam     88       91
# 1    Neha     92       89
#
# Science > 90:
#       Name  Maths  Science
# 0  Satyam     88       91

# %%
import numpy as np

# 2D Arrays (Matrix)
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

print("Matrix A:\n", A)
print("Matrix B:\n", B)

# Matrix Addition
print( A + B)

# Matrix Subtraction
print(A - B)

# Element-wise Multiplication
print( A * B)

# Matrix Multiplication (dot product)
print(np.dot(A, B))

# Transpose
print( A.T)
# Out:
# Matrix A:
#  [[1 2]
#  [3 4]]
# Matrix B:
#  [[5 6]
#  [7 8]]
# [[ 6  8]
#  [10 12]]
# [[-4 -4]
#  [-4 -4]]
# [[ 5 12]
#  [21 32]]
# [[19 22]
#  [43 50]]
# [[1 3]
#  [2 4]]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = [[1], [2], [3], [4], [5]]
y = [2, 4, 6, 8, 10]

X_train, X_test, y_train, y_test = train_test_split(X, y)

model = LinearRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

print(predictions)
# Out:
# [2. 4.]

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Dummy dataset
x = torch.tensor([[1.0], [2.0], [3.0]])
y = torch.tensor([[2.0], [4.0], [6.0]])

# Simple model
model = nn.Linear(1, 1)

# Loss & Optimizer
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Training
for epoch in range(100):
    pred = model(x)
    loss = criterion(pred, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

print(model(torch.tensor([[4.0]])))
# Out:
# tensor([[7.6717]], grad_fn=<AddmmBackward0>)

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=(1,))
])

model.compile(optimizer='sgd', loss='mse')

X = [1, 2, 3, 4]
y = [2, 4, 6, 8]

model.fit(X, y, epochs=100)

print(model.predict([5]))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-2469498780> in <cell line: 0>()
#      10 y = [2, 4, 6, 8]
#      11
# ---> 12 model.fit(X, y, epochs=100)
#      13
#      14 print(model.predict([5]))
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# ...

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = [5, 15, 25, 35]

plt.scatter(x, y, color='green', marker='o')
plt.title("Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

marks = [50, 60, 70, 60, 55, 65, 75, 80, 85, 70, 60]

plt.hist(marks, bins=5, color='skyblue', edgecolor='black')
plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [5,4,3,2,1]

plt.scatter(x, y, color='green', marker='*')
plt.title("inverse relation")
plt.xlabel("Age")
plt.ylabel("Score")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

marks = [45, 67, 89, 56, 55, 72, 70, 68, 66, 74, 90, 60, 58]

plt.hist(marks, bins=5, color='skyblue', edgecolor='black')
plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("No. of Students")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y1 = [10, 20, 25, 30]
y2 = [30, 25, 20, 15]

plt.subplot(2, 2, 1)  # 1 row, 2 columns, 1st plot
plt.plot(x, y1)
plt.title("Line 1")

plt.subplot(3, 2, 2)  # 1 row, 2 columns, 2nd plot
plt.plot(x, y2)
plt.title("Line 2")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-6-781195fb5e36>:15: UserWarning: tight_layout not applied: number of rows in subplot specifications must be multiples of one another.
#   plt.tight_layout()

# %%
# Pie Chart
import matplotlib.pyplot as plt
tasks = ['Study', 'Game']
time = [2, 3]
plt.pie(time, labels=tasks, autopct='%1.1f%%')
plt.title("Task Time")
plt.show()

# Subplot Example
plt.subplot(1, 2, 1)
plt.plot([1, 2], [3, 4])
plt.subplot(1, 2, 2)
plt.bar(['A', 'B'], [5, 6])
plt.tight_layout()
plt.show()

# %%
import numpy as np

# Random integers from 0 to 100 in a 3x3 matrix
data = np.random.randint(0, 50, size=(4,4))
print("Random Matrix:\n", data)
print("Mean:", np.mean(data))
print("Median:", np.median(data))
print("Standard Deviation:", np.std(data))
print("Max:", np.max(data))
print("Min:", np.min(data))import numpy as np

# Random integers from 0 to 100 in a 3x3 matrix
data = np.random.randint(0, 50, size=(4,4))
print("Random Matrix:\n", data)
print("Mean:", np.mean(data))
print("Median:", np.median(data))
print("Standard Deviation:", np.std(data))
print("Max:", np.max(data))
print("Min:", np.min(data))
# Out:
# Random Matrix:
#  [[49  4 19 31]
#  [47 38  3 34]
#  [34 22 28 46]
#  [48 48 38  3]]
# Mean: 30.75
# Median: 34.0
# Standard Deviation: 15.868601072558349
# Max: 49
# Min: 3

# %%
import matplotlib.pyplot as plt

# Sample data
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']
temperature = [30, 32, 31, 29, 33]

plt.plot(days, temperature, marker='o', color='green')
plt.title("Temperature Over Days")
plt.xlabel("Days")
plt.ylabel("Temperature (°C)")
plt.grid(True)
plt.show()
# Bar chart of same data
plt.bar(days, temperature, color='skyblue')
plt.title("Temperature Bar Chart")
plt.xlabel("Days")
plt.ylabel("Temperature (°C)")
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
tasks = ['Exercise', 'DSA', 'Reading', 'Gaming']
time_spent = [30, 60, 20, 90]

# Plotting Pie Chart
plt.pie(time_spent, labels=tasks)
plt.title("Time Spent on Daily Activities")
plt.show()

# %%
import pandas as pd

data = {
    'Day': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri'],
    'Study_Hours': [2, 2.5, 3, 1.5, 3.5],
    'Sleep_Hours': [7, 6.5, 6, 7.5, 6]
}

df = pd.DataFrame(data)
print(df)
import matplotlib.pyplot as plt

plt.plot(df['Day'], df['Study_Hours'], label='Study', marker='o')
plt.plot(df['Day'], df['Sleep_Hours'], label='Sleep', marker='o')
plt.title('Study vs Sleep')
plt.xlabel('Days')
plt.ylabel('Hours')
plt.legend()
plt.show()
plt.bar(df['Day'], df['Study_Hours'], color='orange')
plt.title('Study Hours')
plt.xlabel('Day')
plt.ylabel('Hours')
plt.show()
# Pie chart for total time spent this week
total = df['Study_Hours'].sum()
labels = df['Day']
values = df['Study_Hours']

plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.title('Weekly Study Distribution')
plt.show()
# Out:
#    Day  Study_Hours  Sleep_Hours
# 0  Mon          2.0          7.0
# 1  Tue          2.5          6.5
# 2  Wed          3.0          6.0
# 3  Thu          1.5          7.5
# 4  Fri          3.5          6.0
